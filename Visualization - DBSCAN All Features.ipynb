# %%
import pandas as pd
import numpy as np
from data_columns import childhood, demographic, diagnosis, all
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cluster_df = pd.read_csv('./data/clustering_all_features.csv')
cluster_df.shape
# Out:
# (4959, 123)

# %%
childhood_num_columns = ["CH13","CH14","CH16","CH21","CH22","CH24","CH38","CH43","CH45"]
childhood_columns = childhood()
c_list = [ i for i in childhood_columns if i not in childhood_num_columns]

n_features = len(c_list)
n_cols = 4  
n_rows = int(np.ceil(n_features / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4 * n_rows))
axes = axes.flatten()

for i, feature in enumerate(c_list):
    ax = axes[i]
    crosstab = pd.crosstab(cluster_df['cluster'], cluster_df[feature], normalize='index')
    crosstab.plot(kind='bar', stacked=True, colormap='tab20', ax=ax, legend=False)
    ax.set_title(f"{feature}")
    ax.set_ylabel("Proportion")
    ax.set_xlabel("Cluster")

for j in range(len(c_list), len(axes)):
    fig.delaxes(axes[j])

handles, labels = ax.get_legend_handles_labels()
fig.tight_layout(rect=[0, 0, 0.85, 1]) 

plt.show()

# %%
demographic_num_columns = ["HHSIZE","AGE"]
demographic_columns = demographic()
d_list = [ i for i in demographic_columns if i not in demographic_num_columns]

n_features = len(d_list)
n_cols = 4  
n_rows = int(np.ceil(n_features / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4 * n_rows))
axes = axes.flatten()

for i, feature in enumerate(d_list):
    ax = axes[i]
    crosstab = pd.crosstab(cluster_df['cluster'], cluster_df[feature], normalize='index')
    crosstab.plot(kind='bar', stacked=True, colormap='tab20', ax=ax, legend=False)
    ax.set_title(f"{feature}")
    ax.set_ylabel("Proportion")
    ax.set_xlabel("Cluster")

for j in range(len(d_list), len(axes)):
    fig.delaxes(axes[j])

handles, labels = ax.get_legend_handles_labels()
fig.tight_layout(rect=[0, 0, 0.85, 1]) 

plt.show()

# %%
di_list = diagnosis()

n_features = len(di_list)
n_cols = 4  
n_rows = int(np.ceil(n_features / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4 * n_rows))
axes = axes.flatten()

for i, feature in enumerate(di_list):
    ax = axes[i]
    crosstab = pd.crosstab(cluster_df['cluster'], cluster_df[feature], normalize='index')
    crosstab.plot(kind='bar', stacked=True, colormap='tab20', ax=ax, legend=False)
    ax.set_title(f"{feature}")
    ax.set_ylabel("Proportion")
    ax.set_xlabel("Cluster")

for j in range(len(di_list), len(axes)):
    fig.delaxes(axes[j])

handles, labels = ax.get_legend_handles_labels()
fig.tight_layout(rect=[0, 0, 0.85, 1]) 

plt.show()
